# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_stats = pd.DataFrame({"Jahr": range(1980,2021), "Eingeloeste_Autos": range(1980,2021), "Todesfälle": range(1980,2021), "Todeswahrscheinlichkeit_steinschlag": 0.0000713, "Todeswahrscheinlichkeit_Grenzwert":0.0001})
df_stats.set_index("Jahr", inplace=True)

# %%
#read csv with multiple sheets
year = 1980
lst_tote = []
lst_year = []
while year <= 2020:
    df = pd.read_excel("je-d-11.06.01.01.01.xlsx", sheet_name=str(year), header=[2,3,4,5], index_col=0, nrows=32)
    df_stats["Todesfälle"][year] = df[("Verunfallte Personen","Alle Verunfallten", "Getötete", "Unnamed: 7_level_3")]["Total"]
    year += 1
# Out:
# /var/folders/f0/pqy2clvx0nv38xm_npv8fklm0000gn/T/ipykernel_11434/1449812388.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_stats["Todesfälle"][year] = df[("Verunfallte Personen","Alle Verunfallten", "Getötete", "Unnamed: 7_level_3")]["Total"]

# %%
df_stats
# Out:
#       Eingeloeste_Autos  Todesfälle  Todeswahrscheinlichkeit_steinschlag  \
# Jahr
# 1980               1980        1246                             0.000071
# 1981               1981        1165                             0.000071
# 1982               1982        1192                             0.000071
# 1983               1983        1159                             0.000071
# 1984               1984        1101                             0.000071
# 1985               1985         908                             0.000071
# 1986               1986        1034                             0.000071
# 1987               1987         952                             0.000071
# 1988               1988         945                             0.000071
# 1989               1989         925                             0.000071
# 1990               1990         954                             0.000071
# 1991               1991         860                             0.000071
# ...

# %%
df_2010_2021 = pd.read_excel("cc-d-11.03.02.01.01.xlsx", sheet_name="2010-2021", header=1, index_col=1, nrows=10)
df_1990_2009 = pd.read_excel("cc-d-11.03.02.01.01.xlsx", sheet_name="1990-2009", header=1, index_col=1, nrows=10)
df_1980_1989 = pd.read_excel("cc-d-11.03.02.01.01.xlsx", sheet_name="1980-1989", header=1, index_col=1, nrows=10)

# %%
df_1980_1989.dropna(axis=0, how="all", inplace=True)

# %%
df_1980_1989.rename(columns={"1988 4)": 1988}, inplace=True)

# %%
df_1980_1989
# Out:
#                                FAZG       1980       1981       1982  \
# Fahrzeuggruppe
# Total Fahrzeuge                 1-7  2839474.0  3026363.0  3152610.0
# Total Motorfahrzeuge            1-6  2702266.0  2877169.0  2998001.0
# Personenwagen                     1  2246752.0  2394455.0  2473318.0
# Personentransportfahrzeuge 1)     2    11087.0    11122.0    11341.0
# Sachentransportfahrzeuge          3   169402.0   167846.0   178313.0
# Landwirtschaftsfahrzeuge 2)       4   137685.0   151238.0   156631.0
# Industriefahrzeuge 2)             5        NaN        NaN        NaN
#
#                                     1983       1984       1985       1986  \
# Fahrzeuggruppe
# Total Fahrzeuge                3234271.0  3283000.0  3392447.0  3487603.0
# Total Motorfahrzeuge           3074207.0  3119073.0  3221607.0  3306090.0
# Personenwagen                  2520610.0  2552132.0  2617164.0  2678911.0
# Personentransportfahrzeuge 1)    11255.0    10853.0    10771.0    10800.0
# ...

# %%
df_1980_1989
# Out:
#                                FAZG       1980       1981       1982  \
# Fahrzeuggruppe
# Total Fahrzeuge                 1-7  2839474.0  3026363.0  3152610.0
# Total Motorfahrzeuge            1-6  2702266.0  2877169.0  2998001.0
# Personenwagen                     1  2246752.0  2394455.0  2473318.0
# Personentransportfahrzeuge 1)     2    11087.0    11122.0    11341.0
# Sachentransportfahrzeuge          3   169402.0   167846.0   178313.0
# Landwirtschaftsfahrzeuge 2)       4   137685.0   151238.0   156631.0
# Industriefahrzeuge 2)             5        NaN        NaN        NaN
#
#                                     1983       1984       1985       1986  \
# Fahrzeuggruppe
# Total Fahrzeuge                3234271.0  3283000.0  3392447.0  3487603.0
# Total Motorfahrzeuge           3074207.0  3119073.0  3221607.0  3306090.0
# Personenwagen                  2520610.0  2552132.0  2617164.0  2678911.0
# Personentransportfahrzeuge 1)    11255.0    10853.0    10771.0    10800.0
# ...

# %%
df_1990_2009.dropna(axis=0, how="all", inplace=True)

# %%
df_1990_2009
# Out:
#                                FAZG       1990       1991       1992  \
# Fahrzeuggruppe
# Total Fahrzeuge                 1-7  3998745.0  4110225.0  4169263.0
# Total Motorfahrzeuge            1-6  3776829.0  3880700.0  3934981.0
# Personenwagen                     1  2985397.0  3057798.0  3091228.0
# Personentransportfahrzeuge 1)     2    31180.0    32968.0    34136.0
# Sachentransportfahrzeuge          3   252136.0   257646.0   256611.0
# Landwirtschaftsfahrzeuge          4   162932.0   165571.0   169277.0
# Industriefahrzeuge                5    45920.0    46938.0    47281.0
#
#                                     1993       1994       1995       1996  \
# Fahrzeuggruppe
# Total Fahrzeuge                4204171.0  4280667.0  4375982.0  4435033.0
# Total Motorfahrzeuge           3964638.0  4033928.0  4120464.0  4172630.0
# Personenwagen                  3109523.0  3165042.0  3229176.0  3268093.0
# Personentransportfahrzeuge 1)    34852.0    35676.0    36517.0    37662.0
# ...

# %%
df_2010_2020 = df_2010_2021.drop(columns=[2021])
df_2010_2020
# Out:
#                                           FAZG     2010     2011     2012  \
# Fahrzeuggruppe
# Total Fahrzeuge (ohne Mofas)               1-7  5729451  5861397  5996138
# Total Motorfahrzeuge (ohne Mofas)          1-6  5359955  5480302  5605328
# Personenwagen                                1  4075825  4163003  4254725
# Personentransportfahrzeuge 1                 2    52751    55422    58278
# Sachentransportfahrzeuge                     3   335200   348553   361926
# Landwirtschaftsfahrzeuge                     4   186485   187130   188358
# Industriefahrzeuge                           5    58492    60324    62219
# Motorräder                                   6   651202   665870   679822
# Anhänger                                     7   369496   381095   390810
# Motorfahrräder \ninkl. schnelle E-Bikes 2  NaN   139548   142834   145984
#
#                                               2013     2014     2015     2016  \
# Fahrzeuggruppe
# ...

# %%
df_2010_2021.drop(columns=["FAZG"], inplace=True)
df_1980_1989.drop(columns=["FAZG"], inplace=True)
df_1990_2009.drop(columns=["FAZG"], inplace=True)

# %%
df_1980_1989.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, Total Fahrzeuge to Industriefahrzeuge 2)
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   1980    6 non-null      float64
#  1   1981    6 non-null      float64
#  2   1982    6 non-null      float64
#  3   1983    6 non-null      float64
#  4   1984    6 non-null      float64
#  5   1985    6 non-null      float64
#  6   1986    6 non-null      float64
#  7   1987    6 non-null      float64
#  8   1988    7 non-null      float64
#  9   1989    7 non-null      float64
# dtypes: float64(10)
# memory usage: 616.0+ bytes

# %%
for i in df_2010_2020.columns:
    df_stats["Eingeloeste_Autos"][i] = df_2010_2020[i]["Total Fahrzeuge (ohne Mofas)"]
for i in df_1990_2009.columns:
    df_stats["Eingeloeste_Autos"][i] = df_1990_2009[i]["Total Fahrzeuge"]
for i in df_1980_1989.columns:
    df_stats["Eingeloeste_Autos"][i] = df_1980_1989[i]["Total Fahrzeuge"]
# Out:
# /var/folders/f0/pqy2clvx0nv38xm_npv8fklm0000gn/T/ipykernel_11434/3374272595.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_stats["Eingeloeste_Autos"][i] = df_2010_2020[i]["Total Fahrzeuge (ohne Mofas)"]
# /var/folders/f0/pqy2clvx0nv38xm_npv8fklm0000gn/T/ipykernel_11434/3374272595.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_stats["Eingeloeste_Autos"][i] = df_1990_2009[i]["Total Fahrzeuge"]
# /var/folders/f0/pqy2clvx0nv38xm_npv8fklm0000gn/T/ipykernel_11434/3374272595.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df_stats["Todeswahrscheinlichkeit"] = df_stats["Todesfälle"] / df_stats["Eingeloeste_Autos"]
df_stats
# Out:
#       Eingeloeste_Autos  Todesfälle  Todeswahrscheinlichkeit_steinschlag  \
# Jahr
# 1980            2839474        1246                             0.000071
# 1981            3026363        1165                             0.000071
# 1982            3152610        1192                             0.000071
# 1983            3234271        1159                             0.000071
# 1984            3283000        1101                             0.000071
# 1985            3392447         908                             0.000071
# 1986            3487603        1034                             0.000071
# 1987            3588595         952                             0.000071
# 1988            3699095         945                             0.000071
# 1989            3842719         925                             0.000071
# 1990            3998745         954                             0.000071
# 1991            4110225         860                             0.000071
# ...

# %%
#lineplot with seaborn library and probability of death
plt.subplots(figsize=(10,5))
sns.lineplot(x="Jahr", y="Todeswahrscheinlichkeit_Grenzwert", data=df_stats, label="Grenzwert", linewidth=2, color="green")
sns.lineplot(x="Jahr", y="Todeswahrscheinlichkeit_steinschlag", data=df_stats, label="Kantonstrasse", linewidth=2, color="orange")
plt.title("Interpretation Grenzwert Todesfallwahrscheinlichkeit", fontsize=12)
sns.set(font_scale=1)
plt.ylim(0, 0.0005)
plt.show()

# %%
#lineplot with seaborn library and probability of death
plt.subplots(figsize=(10,5))
sns.lineplot(x="Jahr", y="Todeswahrscheinlichkeit", data=df_stats, label="Strassenverkehr", linewidth=2)
sns.lineplot(x="Jahr", y="Todeswahrscheinlichkeit_steinschlag", data=df_stats, label="Kantonstrasse", linewidth=2, color="orange")
#sns.lineplot(x="Jahr", y="Todeswahrscheinlichkeit_Grenzwert", data=df_stats, label="Grenzwert", linewidth=2, color="green")
plt.title("Vergleich Todesfallwahrscheinlichkeit Strassenverkehr über Zeit mit Todesfallwahrscheinlichkeit Kantonsstrasse", fontsize=12)
sns.set(font_scale=1)
plt.ylim(0, 0.0005)
plt.show()
