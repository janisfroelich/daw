# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
header = ["Kanton","Total","Getötete","Total Verletzte","Schwerverletzte","Leichtverletzte"]

# %%
# read csv je-d-11.06.01.01.01.xlsx with mutliple header (row 2-5) and skip first row
unfaelle = pd.read_excel("je-d-11.06.01.01.01.xlsx", skiprows=5, header=None, sheet_name="2021", index_col=None, usecols=range(6), nrows=32)

# %%
header_fuss=header.copy()
index_fuss = unfaelle.index

# %%
index_test = unfaelle.index

# %%
unfaelle
# Out:
#                     0      1    2      3     4      5
# 0               Total  17436  194  17242  3714  13528
# 1     Genferseeregion   3411   50   3361   837   2524
# 2               Waadt   1677   24   1653   326   1327
# 3              Wallis    601   12    589   134    455
# 4                Genf   1133   14   1119   377    742
# 5   Espace Mittelland   4178   36   4142   863   3279
# 6                Bern   2481   17   2464   553   1911
# 7            Freiburg    571    6    565   129    436
# 8           Solothurn    602    8    594    75    519
# 9           Neuenburg    368    4    364    62    302
# 10               Jura    156    1    155    44    111
# 11    Nordwestschweiz   1806   18   1788   389   1399
# 12        Basel-Stadt    305    5    300    95    205
# 13   Basel-Landschaft    448    4    444    66    378
# 14             Aargau   1053    9   1044   228    816
# 15             Zürich   3332   20   3312   575   2737
# ...

# %%
unfaelle.columns=header

# %%
unfaelle
# Out:
#                Kanton  Total  Getötete  Total Verletzte  Schwerverletzte  \
# 0               Total  17436       194            17242             3714
# 1     Genferseeregion   3411        50             3361              837
# 2               Waadt   1677        24             1653              326
# 3              Wallis    601        12              589              134
# 4                Genf   1133        14             1119              377
# 5   Espace Mittelland   4178        36             4142              863
# 6                Bern   2481        17             2464              553
# 7            Freiburg    571         6              565              129
# 8           Solothurn    602         8              594               75
# 9           Neuenburg    368         4              364               62
# 10               Jura    156         1              155               44
# 11    Nordwestschweiz   1806        18             1788              389
# ...

# %%
unfaelle = unfaelle.drop(columns=["Total","Total Verletzte"])

# %%
unfaelle
# Out:
#                Kanton  Getötete  Schwerverletzte  Leichtverletzte
# 0               Total       194             3714            13528
# 1     Genferseeregion        50              837             2524
# 2               Waadt        24              326             1327
# 3              Wallis        12              134              455
# 4                Genf        14              377              742
# 5   Espace Mittelland        36              863             3279
# 6                Bern        17              553             1911
# 7            Freiburg         6              129              436
# 8           Solothurn         8               75              519
# 9           Neuenburg         4               62              302
# 10               Jura         1               44              111
# 11    Nordwestschweiz        18              389             1399
# 12        Basel-Stadt         5               95              205
# ...

# %%
# boxplot of all columns from unfaelle excluding the first row
unfaelle[:][1:].boxplot(figsize=(12,8))
# Out:
# <AxesSubplot:>

# %%
# Which is the most dangerous Kanton?
# Compare in a barchart the amount of Getötete per Kanton
unfaelle[:][1:].groupby(["Kanton"]).sum()["Getötete"].plot(kind="bar", figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='Kanton'>

# %%
# barchart per column per Kanton
unfaelle[:][1:].groupby(["Kanton"]).sum().plot(kind="bar", figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='Kanton'>
